# %% [markdown]
# <h2 id="datos" style="background-color: #80B8D1 ; color: white; padding: 5px;font-size: 20px;">ANEXO J - ACCESO A LOS DATOS</h2>

# %% [markdown]
# Los datos son públicos y se encuentran en la plataforma Kaggle. Se pude acceder mediante el siguiente enlace:
#
# https://www.kaggle.com/datasets/behrad3d/nasa-cmaps
#
# ![KAGGLEpng.png](attachment:KAGGLEpng.png)
#
#
# Como se mencionó inicialmente, de los 4 conjuntos de datos disponbiles, se seleccionó el FD004.
